# %%
from manim import *
import networkx as nx
import numpy as np
import math
# %run funcionesComida.ipynb
# %run Algoritmo-Arbol-Decision.ipynb
# %run contadores.ipynb

# %%
def construir_tabla(self, matriz, tipos1, tipos2):
    submatriz = [[matriz[i][j] for j in tipos2] for i in tipos1]
    escalar_submatriz(submatriz)
    # Extraer columna
    first_column = [submatriz[i][0] for i in range(1, len(submatriz))]
    first_row = submatriz[0][1:]
    comb = [row[1:] for row in submatriz[1:]]
    table = construir_mobject_table(comb, first_column, first_row)
    return table

def escalar_submatriz(submatriz):
    for i in range(len(submatriz)):
        for j in range(len(submatriz[i])):
            submatriz[i][j].scale(0.5)

def construir_mobject_table(comb, first_column, first_row):
    return MobjectTable(
        comb,
        row_labels=first_column,
        col_labels=first_row,
        include_outer_lines=True
    )

# %%
# %%manim -qm -v WARNING Video1Escena1
#
# class Video1Escena1(Scene):
#     def construct(self):
#         cuarto_vacio = self.crear_cuarto_vacio()
#         cuarto_articulos = self.crear_cuarto_con_articulos()
#         chica = self.mostrar_chica()
#         chica_sosteniendo_ropa = self.mostrar_chica_con_ropa()
#         self.pregunta()
#         self.limpiar_pantalla()
#
#         self.mostrar_board()
#         self.mostrar_reglas()
#
#         self.wait(.3)
#         self.limpiar_pantalla()
#
#     def crear_cuarto_vacio(self):
#         cuarto_vacio = SVGMobject("ropa/closet Vacio.svg").scale(3.6)
#         self.add(cuarto_vacio)
#         self.wait(0.2)
#         return cuarto_vacio
#
#     def crear_cuarto_con_articulos(self):
#         cuarto_articulos = SVGMobject("ropa/closet.svg").scale(3.6)
#         self.play(Write(cuarto_articulos), run_time=3.7)
#         self.wait(0.3)
#         return cuarto_articulos
#
#     def mostrar_chica(self):
#         chica = SVGMobject("ropa/chicaRopa.svg").move_to([0, -0.3, 0]).scale(3)
#         self.play(FadeIn(chica), run_time=0.3)
#         self.wait(0.7)
#         return chica
#
#     def mostrar_chica_con_ropa(self):
#         chica_sosteniendo_ropa = SVGMobject("ropa/chicaRopaSosteniendoRopa.svg").move_to([-0.475, -0.3, 0]).scale(3)
#         self.add(chica_sosteniendo_ropa)
#         return chica_sosteniendo_ropa
#
#     def pregunta(self):
#         pregunta_texto = Tex("¿Cuántas combinaciones se pueden hacer si tengo tales prendas o tales colores?").scale(.7).move_to([0,3,0])
#         self.play(Write(pregunta_texto), run_time = 3)
#         self.wait(.5)
#
#     def limpiar_pantalla(self):
#         self.clear()
#
#     def mostrar_board(self):
#         board = SVGMobject("ropa/board.svg").scale(3.6)
#         self.add(board)
#
#     def mostrar_reglas(self):
#         reglas_texto = Tex("Existen 2 reglas:", color=BLACK).scale(1.7).move_to([-1, 2.5, 0])
#         self.play(Write(reglas_texto))
#
#         figuras = [
#             (Circle, PURE_GREEN, -5),
#             (Circle, PURE_BLUE, -3),
#             (Circle, PURE_RED, -1),
#             (Triangle, PURE_GREEN, 1),
#             (Triangle, PURE_BLUE, 3),
#             (Triangle, PURE_RED, 5)
#         ]
#
#         for figura, color, coordenada_x in figuras:
#             self.mostrar_figura(figura, color, coordenada_x)
#
#         self.wait(2)
#
#         principio_suma_texto = Tex("-Principio de la suma", color=BLACK).scale(1.4).move_to([-1.45, 1.2, 0])
#         self.play(Write(principio_suma_texto), run_time=1.13)
#         principio_multiplicacion_texto = Tex("-Principio de la multiplicación", color=BLACK).scale(1.4).move_to([-0.1, 0.2, 0])
#         self.play(Write(principio_multiplicacion_texto), run_time=1.4)
#
#     def mostrar_figura(self, tipo_figura, color, coordenada_x):
#         figura = tipo_figura().set_opacity(1).scale(0.6).set_color(color).move_to([coordenada_x, -2, 0])
#         self.play(FadeIn(figura), run_time=0.5)

# %%
# %%manim -qm -v WARNING video1escena2
#
# class video1escena2(Scene):
#     def construct(self):
#         restaurante(self)
# Out:
# <video src="media\jupyter\video1escena2@2024-07-22@20-20-39.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Video1Escena3
#
# class Video1Escena3(Scene):
#     def construct(self):
#         tipos_pasta, pasta, espagueti, fusili, macaroni = tipos_pasta(self)
#         tipos_salsa, salsa, salsa_pomodoro, salsa_parmesano, salsa_ajo = tipos_salsa(self)
#         pregunta = self.mostrar_pregunta()
#
#         self.ocultar_elementos(pregunta, tipos_pasta, pasta, tipos_salsa, salsa, espagueti, macaroni)
#
#         arbol_simple = arbolSencillo(self,fusili,salsa_pomodoro,salsa_parmesano,salsa_ajo)
#         self.play(FadeOut(arbol_simple))
#
#     def mostrar_pregunta(self):
#         pregunta_opciones = Text('¿Cuántas opciones tienes para elegir?  ', color=RED, font_size = 30)
#         self.play(Write(pregunta_opciones))
#         self.wait(2)
#         return pregunta_opciones
#
#     def ocultar_elementos(self, pregunta, tipos_pasta, pasta, tipos_salsa, salsa, espagueti, macaroni):
#         self.play(FadeOut(pregunta), FadeOut(tipos_pasta), FadeOut(pasta), FadeOut(tipos_salsa), FadeOut(salsa),
#           FadeOut(espagueti), FadeOut(macaroni)
#          )
# Out:
# <video src="media\jupyter\Video1Escena3@2024-07-22@20-20-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Video1Escena4
#
# class Video1Escena4(Scene):
#     def construct(self):
#         tipos_1 = [0, 1, 2, 3]
#         tipos_2 = [0, 1, 2, 3]
#
#         matriz_completa = copy.deepcopy(imagenesArbol())
#         arbol_niveles_1, arbol_1, coordenadas_1, aristas_1 = construir_arbol(matriz_completa, tipos_1, tipos_2)
#         crear_arbol_niveles(self, arbol_niveles_1)
#         self.wait(1)
#         contador_comb(self, arbol_niveles_1, RIGHT, 1.2)
#
#         self.animar_escalamiento_platillos(arbol_niveles_1, 1.2, .2)
#         self.animar_escalamiento_platillos(arbol_niveles_1, 5/6, .5)
#
#         self.escribir()
#
#         self.animar_escalamiento_pasta(arbol_niveles_1, 1.2, .2)
#         self.animar_escalamiento_pasta(arbol_niveles_1, 5/6, .2)
#         self.crear_operaciones(arbol_niveles_1)
#         self.transformar_arbol(arbol_1, tipos_1, tipos_2)
#         self.crear_multiplicacion()
#
#
#     def animar_escalamiento_platillos(self, arbol_niveles_1, escalar, duracion):
#         self.play(arbol_niveles_1[3][0].animate.scale(escalar),arbol_niveles_1[3][1].animate.scale(escalar),
#           arbol_niveles_1[3][2].animate.scale(escalar),arbol_niveles_1[3][3].animate.scale(escalar),
#           arbol_niveles_1[3][4].animate.scale(escalar),arbol_niveles_1[3][5].animate.scale(escalar),
#           arbol_niveles_1[3][6].animate.scale(escalar),arbol_niveles_1[3][7].animate.scale(escalar),
#           arbol_niveles_1[3][8].animate.scale(escalar))
#
#         self.wait(duracion)
#
#     def escribir(self):
#         texto = Tex("Árbol de decisión",font_size = 50)
#         texto.move_to([4, 3, 0])
#         self.play(Write(texto))
#
#     def animar_escalamiento_pasta(self, arbol_niveles_1, escalar, duracion):
#         self.play(arbol_niveles_1[1][0].animate.scale(escalar),arbol_niveles_1[1][1].animate.scale(escalar),
#                   arbol_niveles_1[1][2].animate.scale(escalar))
#
#         self.wait(duracion)
#
#
#     def animar_salsas(self, arbol_niveles_1, escalar, trans):
#         animaciones_totales = []
#
#         for i in range(0, 3):
#             animaciones = [
#                 arbol_niveles_1[2][3*i].animate.scale(escalar),
#                   arbol_niveles_1[2][3*i+1].animate.scale(escalar),
#                   arbol_niveles_1[2][3*i+2].animate.scale(escalar),
#                   arbol_niveles_1[2][9 + 3*i].animate.set_opacity(trans),
#                   arbol_niveles_1[2][10 + 3*i].animate.set_opacity(trans),
#                   arbol_niveles_1[2][11 + 3*i].animate.set_opacity(trans)]
#
#             animaciones_totales.extend(animaciones)
#
#         return animaciones_totales
#
#     def crear_llaves(self, arbol_niveles_1):
#         self.llaves = []
#         for i in range(3):
#             llave = Tex(r"\}", color=WHITE, font_size=230).next_to(arbol_niveles_1[2][3*i+1], RIGHT, buff=-0.1)
#             self.llaves.append(llave)
#
#         animaciones_totales = self.animar_salsas(arbol_niveles_1, 1.2, .3)
#         animaciones_totales.append(Write(self.llaves[0]))
#         animaciones_totales.append(Write(self.llaves[1]))
#         animaciones_totales.append(Write(self.llaves[2]))
#
#         self.play(*animaciones_totales, run_time=0.6)
#
#     def crear_numeros_tres(self, arbol_niveles_1):
#         llave_1 = self.llaves[0]
#         llave_2 = self.llaves[1]
#         llave_3 = self.llaves[2]
#         num_1 = Integer(number=3, color=WHITE).scale(1.5).next_to(llave_1, RIGHT, buff=0.05)
#         num_2 = Integer(number=3, color=WHITE).scale(1.5).next_to(llave_2, RIGHT, buff=0.05)
#         num_3 = Integer(number=3, color=WHITE).scale(1.5).next_to(llave_3, RIGHT, buff=0.05)
#         self.play(FadeIn(num_1), FadeIn(num_2), FadeIn(num_3), run_time=0.5)
#
#         animaciones_totales_FadeOut = self.animar_salsas(arbol_niveles_1, 5/6, 1)
#
#         animaciones_totales_FadeOut.append(FadeOut(llave_1))
#         animaciones_totales_FadeOut.append(FadeOut(llave_2))
#         animaciones_totales_FadeOut.append(FadeOut(llave_3))
#
#         self.play(*animaciones_totales_FadeOut, run_time=0.7)
#
#         return num_1, num_2, num_3
#
#     def crear_suma(self, num_1, num_2, num_3):
#         self.play(num_1.animate.move_to([2, 1.5, 0]))
#         suma_1 = Tex("+",font_size = 80).next_to(num_1, RIGHT, buff = .05)
#         self.play(FadeIn(suma_1),num_2.animate.move_to([3, 1.5, 0]))
#         suma_2 = Tex("+",font_size = 80).next_to(num_2, RIGHT, buff = .05)
#         self.play(FadeIn(suma_2), num_3.animate.move_to([4, 1.5, 0]))
#         mul_2 = Tex("= 9",font_size = 80).next_to(num_3, RIGHT)
#         self.play(FadeIn(mul_2), run_time = .4)
#         self.wait(2)
#
#
#     def crear_multiplicacion(self):
#         llave_3 = self.llaves[2]
#         self.oval = Ellipse(width=1.5, height=6, color=BLUE, fill_opacity=0, stroke_width=5).move_to([-4,0,0])
#         self.add(self.oval)
#         self.play(Write(self.oval))
#         num_1 = Integer(number=3, color = WHITE).scale(1.5).next_to(llave_3, RIGHT, buff=0.05).move_to([3,.5,0])
#         self.play(Transform(self.oval,num_1))
#         self.mul = Tex("x",font_size = 80).move_to([3.5,.5,0])
#         self.play(FadeIn(self.mul))
#         self.oval_2 = Ellipse(width=.8, height=2.5, color=BLUE, fill_opacity=0, stroke_width=5).move_to([-2,0,0])
#         self.add(self.oval_2)
#         self.play(Write(self.oval_2))
#         num_2 = Integer(number=3, color = WHITE).scale(1.5).next_to(llave_3, RIGHT, buff=0.05).move_to([4,.5,0])
#         self.play(Transform(self.oval_2,num_2))
#         self.mul_2 = Tex("= 9",font_size = 80).next_to(num_2, RIGHT)
#         self.play(FadeIn(self.mul_2))
#         self.wait(1)
#
#     def crear_operaciones(self, arbol_niveles_1):
#         self.crear_llaves(arbol_niveles_1)
#         num_1, num_2, num_3 = self.crear_numeros_tres(arbol_niveles_1)
#         self.crear_suma(num_1, num_2, num_3)
#         self.crear_multiplicacion()
#
#     def transformar_arbol(self, arbol_1, tipos_1, tipos_2):
#         matriz = transpose_matrix(imagenesArbol())
#         arbol_nivel_2, arbol_2,coordenadas_2,aristas_2 = construir_arbol(matriz,tipos_2,tipos_1)
#         self.play(Transform(arbol_1, arbol_2), FadeOut(self.oval), FadeOut(self.mul),FadeOut(self.oval_2),
#                   FadeOut(self.mul_2), run_time = 2.5)
#         self.wait(1)
# Out:
# <video src="media\jupyter\Video1Escena4@2024-07-24@21-22-09.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Video1Escena5
#
#
# class Video1Escena5(Scene):
#     def construct(self):
#         self.tabla_decision_texto = self.crear_texto_tabla_decision()
#         self.play(Write(self.tabla_decision_texto))
#
#         tipos1 = [0, 1, 2, 3]
#         tipos2 = [0, 1, 2, 3]
#         matriz_completa = self.obtener_imagenes_arbol()
#
#         table_dec = self.construir_tabla_decision(matriz_completa, tipos1, tipos2)
#         self.play(table_dec.create(), run_time=0.8)
#         self.wait(1)
#
#         self.animar_rectangulos()
#         self.animar_lineas_tabla(table_dec)
#
#         table_dec_copia = self.resaltar_celda(table_dec)
#         self.play(FadeIn(table_dec_copia), run_time=0.7)
#         self.wait(1.5)
#         self.revertir_celda_resaltada(table_dec_copia)
#
#         numbers = self.contar_combinaciones(table_dec, tipos1, tipos2)
#         self.play(Write(numbers), run_time=2)
#
#         self.ajustar_grupo(table_dec, numbers)
#         self.animar_multiplicacion(3, 3, 9)
#
#         self.mostrar_tabla_2()
#         self.animar_multiplicacion(4, 3, 12)
#         self.mostrar_tabla_3()
#         self.animar_multiplicacion(4, 2, 8)
#         self.wait(1)
#
#     def crear_texto_tabla_decision(self):
#         tabla_decision_text = Tex(r"\text{Tabla de} \\ \text{decisión}", font_size=50)
#         tabla_decision_text.move_to([-4.3, 2.6, 0])
#         return tabla_decision_text
#
#     def obtener_imagenes_arbol(self):
#         return imagenesArbol()
#
#     def construir_tabla_decision(self, matriz_completa, tipos1, tipos2):
#         return construir_tabla(self, matriz_completa, tipos1, tipos2)
#
#     def animar_rectangulos(self):
#         self.crear_y_animar_rectangulo([
#             [5.87, 1.6, 0], [5.87, 3.4, 0], [-2.79, 3.4, 0], [-2.79, 1.6, 0]
#         ], RED)
#
#         self.crear_y_animar_rectangulo([
#             [-2.77, 1.61, 0], [-2.77, -3.4, 0], [-5.87, -3.4, 0], [-5.87, 1.61, 0]
#         ], BLUE)
#
#         self.crear_y_animar_rectangulo([
#             [5.87, 1.63, 0], [5.87, -3.4, 0], [-2.76, -3.4, 0], [-2.76, 1.63, 0]
#         ], YELLOW)
#
#     def crear_y_animar_rectangulo(self, vertices, color):
#         rectangulo = Polygon(*vertices, color=color, fill_opacity=0.5)
#         self.wait(0.5)
#         self.play(FadeIn(rectangulo))
#         self.wait(3)
#         self.play(FadeOut(rectangulo))
#         self.wait(0.6)
#
#     def animar_lineas_tabla(self, table_dec):
#         self.line_r0 = table_dec.get_horizontal_lines()[3]
#         self.line_r1 = table_dec.get_horizontal_lines()[4]
#         self.line_c0 = table_dec.get_vertical_lines()[2]
#         self.line_c1 = table_dec.get_vertical_lines()[3]
#
#         self.play(self.line_r0.animate.set_color(RED).set_stroke(width=10),
#                   self.line_r1.animate.set_color(RED).set_stroke(width=10), run_time=1)
#
#         self.play(self.line_c0.animate.set_color(BLUE).set_stroke(width=10),
#                   self.line_c1.animate.set_color(BLUE).set_stroke(width=10), run_time=1)
#
#     def resaltar_celda(self, table_dec):
#         table_dec_copia = copy.deepcopy(table_dec)
#         table_dec_copia.add_highlighted_cell((3, 2), color=YELLOW)
#         return table_dec_copia
#
#     def revertir_celda_resaltada(self, table_dec_copia):
#         self.play(FadeOut(table_dec_copia),
#                   self.line_r0.animate.set_color(WHITE).set_stroke(width=3),
#                   self.line_r1.animate.set_color(WHITE).set_stroke(width=3),
#                   self.line_c0.animate.set_color(WHITE).set_stroke(width=3),
#                   self.line_c1.animate.set_color(WHITE).set_stroke(width=3))
#
#
#     def contar_combinaciones(self, table_dec, tipos1, tipos2):
#         return contador_comb_tabla(self, table_dec, tipos1, tipos2)
#
#     def ajustar_grupo(self, table_dec, numbers):
#         self.grupo_1 = VGroup(table_dec, numbers, self.tabla_decision_texto)
#         self.play(self.grupo_1.animate.scale(0.9).move_to([-1.29714573, 0, 0]))
#         self.wait(1)
#
#     def animar_multiplicacion(self, num1, num2, resultado):
#         arrow1 = Arrow([-4, -3.4, 0], [4.27, -3.4, 0], color=TEAL_B)
#         arrow2 = Arrow([4.37, -3.33, 0], [4.37, 1.59, 0], color=TEAL_B)
#         num1_obj = Integer(number=num1, color=WHITE).scale(1.5).next_to(arrow1, RIGHT)
#         num2_obj = Integer(number=num2, color=WHITE).scale(1.5).next_to(arrow2, UP)
#
#         self.play(GrowArrow(arrow1))
#         self.play(FadeIn(num1_obj))
#         self.play(GrowArrow(arrow2))
#         self.play(FadeIn(num2_obj))
#         self.wait(2)
#
#         mul = Tex("x", font_size=80).move_to([4.9, 0.5, 0])
#         self.play(num1_obj.animate.move_to([4.4, 0.5, 0]), FadeOut(arrow2),
#                   FadeOut(arrow1), FadeIn(mul), num2_obj.animate.move_to([5.4, 0.5, 0]))
#
#         mul2 = Tex("=", font_size=80).move_to([5.95, 0.5, 0])
#         num3_obj = Integer(number=resultado, color=WHITE).scale(1.5).move_to([6.5, 0.5, 0])
#         self.play(FadeIn(mul2), FadeIn(num3_obj))
#         self.wait(3)
#         self.play(FadeOut(num1_obj), FadeOut(num2_obj), FadeOut(num3_obj), FadeOut(mul), FadeOut(mul2))
#
#     def mostrar_tabla_2(self):
#         tipos1 = [0, 1, 2, 3]
#         tipos2 = [0, 1, 2, 3, 4]
#         matriz2 = self.obtener_imagenes_arbol()
#
#         table_dec2 = self.construir_tabla_decision(matriz2, tipos1, tipos2)
#         table_dec2.scale(0.9).move_to([0, 0, 0])
#
#         numbers2 = self.contar_combinaciones(table_dec2, tipos1, tipos2)
#         self.tabla_decision_texto_2 = copy.deepcopy(self.tabla_decision_texto)
#         self.grupo_2 = VGroup(table_dec2, numbers2, self.tabla_decision_texto_2)
#
#         self.play(FadeOut(self.grupo_1), FadeIn(self.grupo_2))
#         self.wait(1)
#         self.play(self.grupo_2.animate.scale(0.8).move_to([-1.2, 0, 0]))
#
#     def mostrar_tabla_3(self):
#         tipos1 = [0, 1, 2]
#         tipos2 = [0, 1, 2, 3, 4]
#         matriz_completa3 = self.obtener_imagenes_arbol()
#
#         table_dec3 = self.construir_tabla_decision(matriz_completa3, tipos1, tipos2)
#         numbers3 = self.contar_combinaciones(table_dec3, tipos1, tipos2)
#         self.grupo_3 = VGroup(table_dec3, numbers3)
#         self.grupo_3.scale(0.72).move_to([-1.2, 0.6205564, 0])
#         self.play(FadeIn(self.grupo_3), FadeOut(self.grupo_2))
#         self.play(FadeIn(self.tabla_decision_texto_2))
#         self.wait(1)
# Out:
# <video src="media\jupyter\Video1Escena5e@2024-07-29@17-36-06.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING video1escena6
#
# class Video1Escena6(Scene):
#     def construct(self):
#         pizarron = SVGMobject("ropa/board.svg").scale(3.6).move_to([0, 0, 0])
#         self.add(pizarron)
#
#         regla_prod_text = Tex("Principio del Producto", color=BLACK).scale(1.7).move_to([-1, 2.5, 0])
#         self.play(Write(regla_prod_text), run_time=1)
#
#         event_a_text = Tex("Evento A:", color=BLACK).scale(1.2).move_to([-3.5, 1.2, 0])
#         self.play(Write(event_a_text), run_time=1)
#
#         m_opciones = self.escribir_texto_nexto_to("m opciones", evento_A, RIGHT, 2.5 )
#         evento_B = self.escribir_texto_nexto_to("Evento B:", evento_A, 2 * DOWN, 1 )
#         n_opciones = self.escribir_texto_nexto_to("n opciones", evento_B, RIGHT, 2.5)
#         evento_A_y_B = self.escribir_texto_nexto_to("Evento A y Evento B:", evento_B, 3 * DOWN, 2.2)
#         m_n_opciones = self.escribir_texto("m * n opciones", evento_A_y_B, RIGHT, 2.7)
#
#         self.wait(2)
#
#     def escribir_texto_nexto_to(self, texto, centro, direccion, tiempo):
#         escrito = Tex(texto, color=BLACK).scale(1.2).next_to(centro, direccion)
#         self.play(Write(escrito), run_time=tiempo)
#         return escrito
#
#     def agregar_tipos_pasta(self):
#         espagueti = SVGMobject("Food/espagueti.svg").move_to([-1.5, -0.9, 0]).scale(0.48)
#         fusili = SVGMobject("Food/fusili.svg").move_to([-0.5, -0.9, 0]).scale(0.32)
#         macaroni = SVGMobject("Food/macaroni.svg").move_to([0.5, -0.9, 0]).scale(0.32)
#         self.play(FadeIn(espagueti, fusili, macaroni), run_time=0.7)
#         self.wait(0.5)
#
#     def agregar_tipos_salsa(self):
#         salsa_pom = SVGMobject("Food/SalsaPomodoro.svg").move_to([-1.5, -2.5, 0]).scale(0.38)
#         salsa_par = SVGMobject("Food/SalsaParmesano.svg").move_to([-0.5, -2.5, 0]).scale(0.38)
#         salsa_ajo = SVGMobject("Food/SalsaAjo.svg").move_to([0.5, -2.5, 0]).scale(0.38)
#         self.play(FadeIn(salsa_pom, salsa_par, salsa_ajo), run_time=0.7)
#         self.wait(0.5)
# Out:
# <video src="media\jupyter\video1escena6@2024-07-29@21-28-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Video1Escena7
#
# class Video1Escena7(Scene):
#     def construct(self):
#         self.configurar_escena()
#         self.mostrar_principio_producto()
#         self.animar_transformaciones()
#         self.limpiar_escena()
#
#     def configurar_escena(self):
#         self.tipos1, self.pasta, self.espagueti, self.fusili = tipos_pasta_2(self)
#         self.tipos2, self.salsa, self.salsa_pom, self.salsa_par, self.salsa_pes, self.salsa_cham = tipos_salsa_2(self)
#         self.tipos3, self.proteina, self.salmon, self.carne = tipos_proteina(self)
#         self.wait(1)
#
#     def mostrar_principio_producto(self):
#         self.regla_prod_text = Tex("Principio del Producto", font_size=60).move_to([3.5, 2, 0])
#         self.play(Write(self.regla_prod_text))
#
#     def animar_transformaciones(self):
#         self.animar_grupo(VGroup(self.espagueti, self.fusili), 2, 2, True)
#         self.animar_grupo(VGroup(self.salsa_pom, self.salsa_par, self.salsa_pes, self.salsa_cham), 4, 3, True)
#         self.animar_grupo(VGroup(self.salmon, self.carne), 2, 4, False)
#         self.mostrar_resultado_final()
#
#     def animar_grupo(self, grupo, numero, posicion_x, no_ultimo):
#         grupo_copia = grupo.copy()
#         numero = Integer(number=numero, color=WHITE).scale(1.5).move_to([posicion_x, 0.5, 0])
#         self.play(Transform(grupo_copia, numero))
#         multiplicador = Tex("x", font_size=80).move_to([posicion_x + 0.5, 0.5, 0])
#         if no_ultimo:
#             self.play(FadeIn(multiplicador))
#
#     def mostrar_resultado_final(self):
#         igual_signo = Tex("= 16", font_size=80).move_to([5.2, 0.5, 0])
#         self.play(FadeIn(igual_signo))
#         self.wait(1)
#
#     def limpiar_escena(self):
#         grupo = VGroup(self.tipos1, self.pasta, self.tipos2, self.salsa, self.tipos3, self.proteina, self.regla_prod_text)
#         self.play(FadeOut(grupo))
#         self.wait(0.5)
# Out:
# <video src="media\jupyter\Video1Escena7@2024-07-29@18-12-48.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING Video1Escena8
#
# class Video1Escena8(Scene):
#     def construct(self):
#         tipos1 = [0, 1, 2]
#         tipos2 = [0, 1, 3, 4, 5]
#         tipos3 = [0, 1, 2]
#
#         matriz_completa = imagenes_arbol_complicado()
#         arbol_niveles, arbol, coordenadas, aristas = construir_arbol_compl(matriz_completa, tipos1, tipos2, tipos3, 0.85)
#         arbol_dec_text = Tex("Árbol de decisión", font_size=50).move_to([4, 3, 0])
#         self.play(Write(arbol_dec_text))
#         crear_arbol_niveles(self, arbol_niveles)
#         contador_comb_compl(self, arbol_niveles, DOWN, 0.8)
#         self.wait(2)
# Out:
# <video src="media\jupyter\Video1Escena8@2024-07-29@18-23-59.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm -v WARNING video1escena8
#
# class video1escena8(Scene):
#     def construct(self):
#         tipos1 = [0,1,2]
#         tipos2 = [0,1,3,4,5]
#         tipos3 = [0,1,2]
#
#         matrizCompleta = imagenesArbolComplicado()
#         arbolNiveles, arbol,coordenadas,aristas = construirArbolCompl(matrizCompleta,tipos1,tipos2,tipos3, .85)
#         arbolDecText = Tex("Árbol de decisión",font_size = 50)
#         arbolDecText.move_to([4, 3, 0])
#         self.play(Write(arbolDecText))
#         crear_arbol_niveles(self,arbolNiveles)
#         contadorCombCompl(self,arbolNiveles, DOWN, .8)
#         self.wait(2)

# %%
class PrincipioSuma(Scene):
    def construct(self):
        regla_suma_text = Tex("Principio de la Suma", font_size=60).move_to([-3, 3, 0])
        event_a_text = Tex("Evento A:", font_size=50).move_to([-1, 2, 0])
        event_a_man_text = Tex("m opciones", font_size=46).next_to(event_a_text, RIGHT)
        event_b_text = Tex("Evento B:", font_size=50).next_to(event_a_text, 2 * DOWN)
        event_b_man_text = Tex("n opciones", font_size=46).next_to(event_b_text, RIGHT)
        event_a_or_b_text = Tex("Evento A o el evento B:", font_size=50).move_to([-2.59, 0, 0])
        event_a_or_b_man_text = Tex("m + n opciones", font_size=46).next_to(event_a_or_b_text, RIGHT)

        self.play(Write(regla_suma_text), run_time=1)
        self.play(Write(event_a_text), run_time=1)
        self.play(Write(event_a_man_text), run_time=2.5)
        self.play(Write(event_b_text), run_time=1)
        self.play(Write(event_b_man_text), run_time=2.5)
        self.play(Write(event_a_or_b_text), run_time=2.2)
        self.play(Write(event_a_or_b_man_text), run_time=2.7)
        self.wait(1)

        principle_sum = VGroup()
        principle_sum.add(regla_suma_text, event_a_text, event_a_man_text, event_b_text, event_b_man_text,
                          event_a_or_b_text, event_a_or_b_man_text)
        self.play(FadeOut(principle_sum))

# %%
# %%manim -qm -v WARNING Video1Escena9b
#
# class Video1Escena9b(Scene):
#     def construct(self):
#         self.mostrar_postres()
#         self.agregar_numeros()
#         postres_group = VGroup(*list(self.postres.values()), self.numeros_postres)
#         self.play(FadeOut(postres_group))
#         self.principio_suma()
#         self.play(FadeIn(postres_group))
#         self.mostrar_tipos_postres()
#
#     def mostrar_postres(self):
#         postre_positions = {
#             "Pastel-chocolate": [-5, 2.5, 0],
#             "Pastel-red-velvet": [-2, 2.5, 0],
#             "Pastel-zanahoria": [1, 2.5, 0],
#             "Helado-Fresa": [-5, -.5, 0],
#             "Helado-napolitano": [-2, -.5, 0],
#             "Flan": [1, -.5, 0]
#         }
#         postre_scales = {
#             "Pastel-chocolate": .8,
#             "Pastel-red-velvet": .7,
#             "Pastel-zanahoria": .7,
#             "Helado-Fresa": .8,
#             "Helado-napolitano": .9,
#             "Flan": .9
#         }
#
#         # Añade los postres
#         self.postres = {}
#         for nombre, posicion in postre_positions.items():
#             postre = SVGMobject(f"Postre/{nombre}.svg")
#             postre.move_to(posicion).scale(postre_scales[nombre])
#             self.play(Write(postre), run_time=1)
#             self.postres[nombre] = postre
#
#     def agregar_numeros(self):
#         self.numeros_postres = VGroup()
#         for i, nombre in enumerate(self.postres.keys(), 1):
#             num = Integer(number=i).scale(1.2)
#             num.next_to(self.postres[nombre].get_center(), 4 * DOWN)
#             self.play(FadeIn(num), run_time=.2)
#             self.numeros_postres.add(num)
#
#     def mostrar_tipos_postres(self):
#         tipos_postres = {
#             "pasteles": ["Pastel-chocolate", "Pastel-red-velvet", "Pastel-zanahoria"],
#             "helados": ["Helado-Fresa", "Helado-napolitano"],
#             "flan": ["Flan"]
#         }
#
#         for tipo, nombres in tipos_postres.items():
#             text = Tex(f"{len(nombres)} tipos").move_to([5, 3 - 2 * list(tipos_postres.keys()).index(tipo), 0])
#             tipo_text = Tex(f"de {tipo}").next_to(text, DOWN)
#             text_group = VGroup(text, tipo_text)
#             postres_grupo = VGroup(*[self.postres[nombre] for nombre in nombres])
#             postres_grupo_copia = copy.deepcopy(postres_grupo)
#             self.play(Transform(postres_grupo_copia, text_group))
#
#             self.wait(1)
#             self.play(FadeOut(text_group))
#
#     def principio_suma(self):
#         pizarron = SVGMobject("ropa/board.svg").scale(3.6).move_to([0, 0, 0])
#         self.add(pizarron)
#
#         regla_suma = Tex("Principio de la Suma", color = BLACK).scale(1.7).move_to([-1.5, 2.5, 0])
#         self.play(Write(regla_suma), run_time = 1)
#
#         evento_A = Tex("Evento A:", color = BLACK).scale(1.2).move_to([-2.5, 1.2, 0])
#         self.play(Write(evento_A), run_time = 1)
#
#         m_opciones = self.escribir_texto_nexto_to("m opciones", evento_A, RIGHT, 2.5 )
#         evento_B = self.escribir_texto_nexto_to("Evento B:", evento_A, 2 * DOWN, 1 )
#         n_opciones = self.escribir_texto_nexto_to("n opciones", evento_B, RIGHT, 2.5)
#
#         evento_A_o_B = self.escribir_texto_nexto_to("Evento A o Evento B:", evento_B, 3 * DOWN, 2.2)
#
#         m_n_opciones = self.escribir_texto_nexto_to("m + n opciones", evento_A_o_B, RIGHT, 2.7)
#         self.wait(1)
#         prin_suma = VGroup()
#         prin_suma.add(regla_suma,evento_A,m_opciones,evento_B, n_opciones, evento_A_o_B, m_n_opciones, pizarron)
#         self.play(FadeOut(prin_suma))
#
#         self.wait(2)
#
#     def escribir_texto_nexto_to(self, texto, centro, direccion, tiempo):
#         escrito = Tex(texto, color = BLACK).scale(1.2).next_to(centro, direccion)
#         self.play(Write(escrito), run_time=tiempo)
#         return escrito
# Out:
# <video src="media\jupyter\Video1Escena9b@2024-07-29@21-34-09.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
